# %%
import json

# %%
with open('all_colleges.json', 'r') as file:
    # Load JSON data from file
    data = json.load(file)

# %%
data['Utah State University']
# Out:
# {'School_Overall': 4.1,
#  'School_Reputation': 4.2,
#  'School_Location': 4.2,
#  'School_Facilities': 4.4,
#  'School_Food': 3.6,
#  'School_Happiness': 4.4,
#  'School_Opportunities': 3.9,
#  'School_Clubs': 3.8,
#  'School_Safety': 4.6,
#  'School_Social': 4.0,
#  'School_Internet': 3.9,
#  'Comments': {'Great school. Keep in mind its in a very small town, and winters can be brutal. Not a lot of options to eat on campus, but lots of stuff in the surrounding area if you have a car. ': {'Comment_Date': 'Mar 28th, 2023',
#    'Comment_Overall': 4.1,
#    'Comment_Reputation': 5,
#    'Comment_Location': 3,
#    'Comment_Opportunities': 4,
#    'Comment_Facilities': 4,
#    'Comment_Internet': 4,
#    'Comment_Food': 2,
#    'Comment_Clubs': 5,
#    'Comment_Social': 4,
#    'Comment_Happiness': 5,
#    'Comment_Safety': 5},
# ...
