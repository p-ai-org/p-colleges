# %%
import numpy as np
import pandas as pd 
import requests
import string
import statistics 
#Text to emotion
# !pip install emoji
# !wget https://raw.githubusercontent.com/aman2656/text2emotion-library/master/Text2Emotion/__init__.py

import __init__ as te
import plotly.express as px
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.9/240.9 kB 5.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for emoji: filename=emoji-2.2.0-py3-none-any.whl size=234926 sha256=82e89e7b94f64d1711fc95ff735aa696fc015a86335dd3faa0280fc6994dc97b
#   Stored in directory: /root/.cache/pip/wheels/02/3d/88/51a592b9ad17e7899126563698b4e3961983ebe85747228ba6
# Successfully built emoji
# ...
# --2023-05-02 05:24:59--  https://raw.githubusercontent.com/aman2656/text2emotion-library/master/Text2Emotion/__init__.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 212312 (207K) [text/plain]
# Saving to: ‘__init__.py’
#
# ...

# %%
# first, let's make a big dataframe with all of the rate my professors data 
urls = [
    "https://raw.githubusercontent.com/p-ai-org/p-colleges/main/Brian/Rate%20My%20Professor/all_colleges_RMP_1_to_32.json", 
    "https://raw.githubusercontent.com/p-ai-org/p-colleges/main/Brian/Rate%20My%20Professor/all_colleges_RMP_33_to_46.json", 
    "https://raw.githubusercontent.com/p-ai-org/p-colleges/main/Brian/Rate%20My%20Professor/all_colleges_RMP_47_to_51.json",
    "https://raw.githubusercontent.com/p-ai-org/p-colleges/main/Brian/Rate%20My%20Professor/all_colleges_RMP_51_to_161.json", 
    "https://raw.githubusercontent.com/p-ai-org/p-colleges/main/Brian/Rate%20My%20Professor/all_colleges_RMP_1_to_32.json", 
    "https://raw.githubusercontent.com/p-ai-org/p-colleges/main/Brian/Rate%20My%20Professor/all_colleges_RMP_162_to_300.json", 
    "https://raw.githubusercontent.com/p-ai-org/p-colleges/main/Brian/Rate%20My%20Professor/all_colleges_RMP_300_to_397.json", 
    "https://raw.githubusercontent.com/p-ai-org/p-colleges/main/Brian/Rate%20My%20Professor/all_colleges_RMP_398_to_472.json", 
    "https://raw.githubusercontent.com/p-ai-org/p-colleges/main/Brian/Rate%20My%20Professor/all_colleges_RMP_473_to_631.json", 
    "https://raw.githubusercontent.com/p-ai-org/p-colleges/main/Brian/Rate%20My%20Professor/all_colleges_RMP_632_to_753.json", 
    "https://raw.githubusercontent.com/p-ai-org/p-colleges/main/Brian/Rate%20My%20Professor/all_colleges_RMP_754_to_894.json", 
    "https://raw.githubusercontent.com/p-ai-org/p-colleges/main/Brian/Rate%20My%20Professor/all_colleges_RMP_895_to_1022.json", 
    "https://raw.githubusercontent.com/p-ai-org/p-colleges/main/Brian/Rate%20My%20Professor/all_colleges_RMP_1023_to_1344.json", 
    "https://raw.githubusercontent.com/p-ai-org/p-colleges/main/Brian/Rate%20My%20Professor/all_colleges_RMP_1345_to_2357.json", 
    "https://raw.githubusercontent.com/p-ai-org/p-colleges/main/Brian/Rate%20My%20Professor/all_colleges_RMP_2358_to_2940.json"
]

dataframes = []
for url in urls:
  response = requests.get(url)
  data = response.json()
  df = pd.DataFrame(data)
  df = df.T
  dataframes.append(df)

rmp_data_full = pd.concat(dataframes)
rmp_data_full = rmp_data_full.dropna(subset=['Comments'])
display(rmp_data_full.head())
# Out:
#                                      School_Overall School_Reputation  \
# Abilene Christian University                    3.8               4.0
# Abraham Baldwin Agricultural College            3.6               3.6
# Academy of Art University                       3.1               3.2
# Bryn Athyn College                              3.4               3.3
# Adams State University                          3.4               3.3
#
#                                      School_Location School_Facilities  \
# Abilene Christian University                     3.1               3.9
# Abraham Baldwin Agricultural College             3.6               4.0
# Academy of Art University                        3.7               3.1
# Bryn Athyn College                               3.6               4.0
# Adams State University                           3.2               3.8
#
#                                      School_Food School_Happiness  \
# ...

# %%
def filter_comments(dict, lower_benchmark, upper_benchmark):
  '''helper function to get a list of comments from the dictionary in rmp_data["Comments"] based on rating'''
  keys_list = list(dict.keys())
  values_list = list(dict.values())

  filtered_comments = []
  for i in range(len(keys_list)):
    values_dict = values_list[i]
    ratings = list(values_dict.values())[2:]
    median_rating = statistics.median(ratings)
    if median_rating >= lower_benchmark and median_rating <= upper_benchmark: 
      filtered_comments.append(keys_list[i])
  
  return filtered_comments 

def filter_df_by_rating(rmp_data, lower_benchmark, upper_benchmark): 
  ''' filters the rmp data based on the range of ratings we want '''
  new_df = rmp_data.copy()
  new_df["Comments_list"] = new_df["Comments"].apply(lambda x: filter_comments(x, lower_benchmark, upper_benchmark))
  new_df.reset_index(inplace = True)
  new_df.rename(columns = {'index': 'College'}, inplace = True)
  new_df = new_df[["College", "Comments_list"]]
  return new_df

# %%
all_comments_df = filter_df_by_rating(rmp_data_full, 0.0, 5.0)

# %%
all_comments_df
# Out:
#                                    College  \
# 0             Abilene Christian University
# 1     Abraham Baldwin Agricultural College
# 2                Academy of Art University
# 3                       Bryn Athyn College
# 4                   Adams State University
# ...                                    ...
# 2368               Tulsa Community College
# 2369              Tunxis Community College
# 2370                  Tyler Junior College
# 2371                         Union College
# 2372         Universal Technical Institute
#
#                                           Comments_list
# 0     [ACU: BEST school\nALL professors: care genuin...
# 1     [Loved my time there!, ABAC is an awesome scho...
# 2     [This school is 100% a scam. The teachers are ...
# 3     [Most of the professors will work with you 100...
# 4     [Not a great school. Transferred out after one...
# ...                                                 ...
# ...

# %%
# this function just pulls the reviews of a given college from the dataset. It returns the reviews as a list
def reviews(college_name):
  return all_comments_df[all_comments_df['College'] == college_name]['Comments_list'].tolist()[0]

# %%
x = reviews('Pomona College')
print(x)
# Out:
# ['The best LAC there ever is.', "Pomona has been the best decision of my life. You get a diverse, intelligent set of people who are all passionate and you're bound to grow and challenge yourself here. The resources are great, there's some grade inflation, the location is solid and the food is good (with other schools) as well.", "Pomona College has been the best choice of my life. You put a bunch of passionate, intelligent people together and you're going to find a place to grow and challenge yourself. The location is unprecedented, the food supplemented by other schools is great, and overall you'll get motivated people who will all succeed with some effort.", 'Choosing to go to Pomona was the best decision of my life. Amazing professors and amazing people. The other 5Cs make up for what Pomona lacks in food diversity or social scene. I love this place and cannot recommend it enough.', 'Amazing professors and students!', 'Mixed feelings. Read more into the school if you want to go he
# ...

# %%
import nltk
from nltk.corpus import stopwords
import re
import emoji
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')


def removing_shortcuts(text):
    full_words = []
    shortcuts = {'u': 'you', 'y': 'why', 'r': 'are', 'doin': 'doing', 'hw': 'how', 'k': 'okay', 'm': 'am',
                 'b4': 'before',
                 'idc': "i do not care", 'ty': 'thank you', 'wlcm': 'welcome', 'bc': 'because', '<3': 'love',
                 'xoxo': 'love',
                 'ttyl': 'talk to you later', 'gr8': 'great', 'bday': 'birthday', 'awsm': 'awesome', 'gud': 'good',
                 'h8': 'hate',
                 'lv': 'love', 'dm': 'direct message', 'rt': 'retweet', 'wtf': 'hate', 'idgaf': 'hate',
                 'irl': 'in real life', 'yolo': 'you only live once', "don't": "do not", 'g8': 'great',
                 "won't": "will not", 'tbh': 'to be honest', 'caj': 'casual', 'Ikr': 'I know, right?',
                 'omw': 'on my way',
                 'ofc': 'of course', 'Idc': "I don't care", 'Irl': 'In real life', 'tbf': 'To be fair',
                 'obvs': 'obviously', 'v': 'very', 'atm': 'at the moment',
                 'col': 'crying out loud', 'gbu': 'god bless you', 'gby': 'god bless you', 'gotcha': 'I got you',
                 'hehe': 'laughing', 'haha': 'laughing', 'hf': 'have fun',
                 'hry': 'hurry', 'hw': 'hardwork', 'idc': 'i don’t care', 'ikr': 'i know right', 'k': 'ok',
                 'lmao': 'laughing my ass off', 'lol': 'laughing out loud',
                 'n1': 'nice one', 'na': 'not available', 'qt': 'cutie', 'qtpi': 'cutie pie', 'rip': 'rest in peace',
                 'sry': 'sorry', 'tc': 'take care',
                 'thnks': 'thanks', 'thx': 'thanks', 'thnk': 'thanks', 'ttyl': 'talk to you later', 'txt': 'text',
                 'ugh': 'disgusted', 'w8': 'wait', "not sad": "happy"}

    for token in text:
        if token in shortcuts.keys():
            token = shortcuts[token]
        full_words.append(token)
    text = " ".join(full_words)
    return text


def removing_stopwords(text):
    stop_words = set(stopwords.words('english'))
    stop = [x.lower() for x in stop_words]
    return [word for word in text if not word in stopwords.words()]


def lemmatization(words_big):
    lemma = WordNetLemmatizer()
    stemmed_words = [lemma.lemmatize(word, 'v') for word in words_big]
    stemmed_words = [lemma.lemmatize(word, 'n') for word in stemmed_words]
    return " ".join(stemmed_words)


def removing_not(text):
    d = {'not sad': 'Happy', 'not bad': 'Happy', 'not boring': 'Happy', 'not wrong': 'Happy', 'not bored': 'Happy',
         'not jealous': 'Happy', 'not happy': 'Sad', 'not well': 'Sad', 'not suitable': 'Angry', 'not right': 'Angry',
         'not good': 'Sad', 'not excited': 'Angry', 'not funny ': 'Sad', 'not  kind': 'Sad', 'not proud': 'Angry',
         'not cool': 'Angry', 'not funny': 'Angry', 'not kind': 'Angry', 'not open': 'Angry', 'not safe': 'Fear',
         'not enough': 'Empty', 'not know': 'Sad', 'not knowing': 'Sad', 'not believe': 'Angry',
         'not believing': 'Angry',
         'not understand': 'Sad', 'not understanding': 'Sad', 'no doubt': 'Happy', 'not think': 'Sad',
         'not thinking': 'Sad',
         'not recognise': 'Sad', 'not recognising': 'Sad', 'not forget': 'Angry', 'not forgetting': 'Angry',
         'not remember': 'Sad',
         'not remembering': 'Sad', 'not imagine': 'Sad', 'not imagining': 'Sad', 'not mean': 'Sad',
         'not meaning': 'Sad',
         'not agree': 'Angry', 'not agreeing': 'Sad', 'not disagree': 'Happy', 'not disagreeing': 'Happy',
         'not deny': 'Sad',
         'not denying': 'Sad', 'not promise': 'Angry', 'not promising': 'Angry', 'not satisfy': 'Sad',
         'not satisfying': 'Sad',
         'not realise': 'Sad', 'not realising': 'Sad', 'not appear': 'Angry', 'not appearing': 'Angry',
         'not please': 'Sad', 'not pleasing': 'Sad', 'not impress': 'Sad', 'not impressing': 'Sad',
         'not surprise': 'Sad', 'not surprising': 'Sad', 'not concern': 'Sad', 'not concerning': 'Sad',
         'not have': 'Sad', 'not having': 'Sad',
         'not own': 'Sad', 'not owning': 'Sad', 'not possess': 'Sad', 'not possessing': 'Sad', 'not lack': 'Sad',
         'not lacking': 'Sad',
         'not consist': 'Sad', 'not consisting': 'Sad', 'not involve': 'Sad', 'not involving': 'Sad',
         'not include': 'Sad', 'not including': 'Sad', 'not contain': 'Sad',
         'not containing': 'Sad', 'not love': 'Sad', 'not like': 'Angry',
         'not hate': 'Happy', 'not hating': 'Happy', 'not adore': 'Sad', 'not adoring': 'Sad', 'not prefer': 'Sad',
         'not preferring': 'Sad', 'not care': 'Angry', 'not mind': 'Angry', 'not minding': 'Sad',
         'not want': 'Angry', 'not wanting': 'Sad',
         'not need': 'Angry', 'not needing': 'Angry', 'not desire': 'Sad', 'not desiring': 'Sad', 'not wish': 'Sad',
         'not wishing': 'Sad', 'not hope': 'Sad', 'not hoping': 'Sad', 'not appreciate': 'Sad',
         'not appreciating': 'Sad',
         'not value': 'Sad', 'not valuing': 'Sad', 'not owe': 'Sad', 'not owing': 'Sad', 'not seem': 'Sad',
         'not seeming': 'Sad', 'not fit': 'Sad', 'not fitting': 'Sad', 'not depend': 'Sad',
         'not depending': 'Sad', 'not matter': 'Sad', 'not afford': 'Sad', 'not affording': 'Sad', 'not aim': 'Sad',
         'not aiming': 'Sad', 'not attempt': 'Angry', 'not attempting': 'Angry', 'not ask': 'Angry',
         'not asking': 'Angry', 'not arrange': 'Angry', 'not arranging': 'Angry', 'not beg': 'Angry',
         'not begging': 'Angry', 'not begin': 'Angry', 'not beginning': 'Angry', 'not caring': 'Angry',
         'not choose': 'Angry', 'not choosing': 'Angry', 'not claim': 'Angry', 'not claiming': 'Angry',
         'not consent': 'Angry', 'not consenting': 'Angry', 'not continue': 'Angry', 'not continuing': 'Angry',
         'not dare': 'Angry', 'not daring': 'Angry', 'not decide': 'Sad',
         'not deciding': 'Sad', 'not demand': 'Angry', 'not demanding': 'Angry', 'not deserve': 'Angry',
         'not deserving': 'Angry', 'not expect': 'Angry',
         'not expecting': 'Angry', 'not fail': 'Happy', 'not failing': 'Happy', 'not get': 'Sad', 'not getting': 'Sad',
         'not hesitate': 'Sad', 'not hesitating': 'Sad', 'not hurry': 'Happy', 'not hurrying': 'Happy',
         'not intend': 'Sad', 'not intending': 'Sad', 'not learn': 'Angry', 'not learning': 'Angry',
         'not liking': 'Angry', 'not loving': 'Sad', 'not manage': 'Angry',
         'not managing': 'Angry', 'not neglect': 'Sad', 'not neglecting': 'Sad', 'not offer': 'Angry',
         'not offering': 'Angry',
         'not plan': 'Angry', 'not planing': 'Angry', 'not prepare': 'Angry',
         'not preparing': 'Angry', 'not pretend': 'Angry', 'not pretending': 'Angry', 'not proceed': 'Angry',
         'not proceeding': 'Angry',
         'not propose': 'Angry', 'not proposing': 'Sad', 'not refuse': 'Sad', 'not refusing': 'Sad',
         'not start': 'Sad',
         'not starting': 'Sad', 'not stop': 'Happy', 'not stopping': 'Happy', 'not struggle': 'Angry',
         'not struggling': 'Angry',
         'not swear': 'Angry', 'not swearing': 'Angry', 'not threaten': 'Happy', 'not threatening': 'Happy',
         'not try': 'Angry', 'not trying': 'Angry', 'not volunteer': 'Angry',
         'not volunteering': 'Angry', 'not wait': 'Angry', 'not waiting': 'Angry', 'not feel': 'Sad',
         'not feeling': 'Sad', "not able": "Sad", "not do": "Sad"}

    f = re.findall("not\s\w+", text)
    for i in f:
        try:
            text = text.replace(i, d[i])
        except:
            pass
    text = text.lower()
    return text


def removing_contradictions(text):
    if text.count("n't"):
        text = text.replace("n't", " not")
    text = re.sub("ai\snot", "am not", text)
    text = re.sub("wo\snot", "will not", text)
    return text


def emojis_extractor(text):
    emoj = {'Emoji': ['👏 🏾',
 '👏 🏼',
 '👏 🏽',
 '👨 \u200d ❤ ️ \u200d 👨',
 '👩 \u200d ❤ ️ \u200d 👨',
 '👩 \u200d ❤ ️ \u200d 👩',
 '🤤',
 '😘',
 '😋',
 '😛',
 '😝',
 '😜',
 '😂',
 '💪',
 '💪 🏿',
 '💪 🏻',
 '💪 🏾',
 '💪 🏼',
 '💪 🏽',
 '🙏',
 '🙏 🏿',
 '🙏 🏻',
 '🙏 🏾',
 '🙏 🏼',
 '🙏 🏽',
 '🌝',
 '😀',
 '😁',
 '💗',
 '🤝',
 '💟',
 '♥',
 '💘',
 '💝',
 '✔',
 '🌺',
 '🤗',
 '💏',
 '👨 \u200d ❤ ️ \u200d 💋 \u200d 👨',
 '💋',
 '👩 \u200d ❤ ️ \u200d 💋 \u200d 👨',
 '👩 \u200d ❤ ️ \u200d 💋 \u200d 👩',
 '😽',
 '😗',
 '😚',
 '😙',
 '🕺',
 '🕺 🏿',
 '🕺 🏻',
 '🕺 🏾',
 '🕺 🏼',
 '🕺 🏽',
 '💁 \u200d ♂ ️',
 '💁 🏿 \u200d ♂ ️',
 '💁 🏻 \u200d ♂ ️',
 '💁 🏾 \u200d ♂ ️',
 '💁 🏼 \u200d ♂ ️',
 '💁 🏽 \u200d ♂ ️',
 '🤓',
 '👐',
 '👐 🏿',
 '👐 🏻',
 '👐 🏾',
 '👐 🏼',
 '👐 🏽',
 '🙌',
 '🙌 🏿',
 '🙌 🏻',
 '🙌 🏾',
 '🙌 🏼',
 '🙌 🏽',
 '😌',
 '🤣',
 '🤘',
 '🤘 🏿',
 '🤘 🏻',
 '🤘 🏾',
 '🤘 🏼',
 '🤘 🏽',
 '😴',
 '🙂',
 '😇',
 '😍',
 '😃',
 '😆',
 '😅',
 '😄',
 '😊',
 '😎',
 '👍',
 '👍 🏿',
 '👍 🏻',
 '👍 🏾',
 '👍 🏼',
 '👍 🏽',
 '💕',
 '✌',
 '✌ 🏿',
 '✌ 🏻',
 '✌ 🏾',
 '✌ 🏼',
 '✌ 🏽',
 '🖖',
 '🖖 🏿',
 '🖖 🏻',
 '🖖 🏾',
 '🖖 🏼',
 '🖖 🏽',
 '👋',
 '👋 🏿',
 '👋 🏻',
 '👋 🏾',
 '👋 🏼',
 '👋 🏽',
 '😉',
 '💃',
 '💃 🏿',
 '💃 🏻',
 '💃 🏾',
 '💃 🏼',
 '💃 🏽',
 '💛',
 '🤙',
 '🤙 🏿',
 '🤙 🏻',
 '🤙 🏾',
 '🤙 🏼',
 '🤙 🏽',
 '👏',
 '👏 🏿',
 '👏 🏻',
 '💓',
 '😥',
 '😞',
 '😓',
 '🤕',
 '😷',
 '🤒',
 '😶',
 '☹',
 '😦',
 '😭',
 '🤥',
 '😐',
 '😔',
 '😪',
 '🙁',
 '😫',
 '🙃',
 '😩',
 '😟',
 '🤐',
 '💔',
 '😑',
 '😤',
 '🤦 \u200d ♂ ️',
 '🤦 🏿 \u200d ♂ ️',
 '🤦 🏻 \u200d ♂ ️',
 '🤦 🏾 \u200d ♂ ️',
 '🤦 🏼 \u200d ♂ ️',
 '🤦 🏽 \u200d ♂ ️',
 '🙅 \u200d ♂ ️',
 '🙅 🏿 \u200d ♂ ️',
 '🇬 🇱',
 '🙅 🏾 \u200d ♂ ️',
 '🙅 🏼 \u200d ♂ ️',
 '🙅 🏽 \u200d ♂ ️',
 '🤷 \u200d ♂ ️',
 '🤷 🏿 \u200d ♂ ️',
 '🤷 🏻 \u200d ♂ ️',
 '🤷 🏾 \u200d ♂ ️',
 '🖕',
 '🖕 🏿',
 '🖕 🏻',
 '🖕 🏾',
 '🖕 🏼',
 '🖕 🏽',
 '👊',
 '👊 🏿',
 '👊 🏻',
 '👊 🏾',
 '👊 🏼',
 '👊 🏽',
 '😣',
 '🤦',
 '🤦 🏿',
 '🤦 🏻',
 '🤦 🏾',
 '🤦 🏼',
 '🤦 🏽',
 '🤷',
 '🤷 🏿',
 '🤷 🏻',
 '🤷 🏾',
 '🤷 🏼',
 '🤷 🏽',
 '😡',
 '😈',
 '😏',
 '👎',
 '👎 🏿',
 '👎 🏻',
 '👎 🏾',
 '👎 🏼',
 '👎 🏽',
 '😒',
 '🙅 \u200d ♀ ️',
 '🙅 🏿 \u200d ♀ ️',
 '🙅 🏻 \u200d ♀ ️',
 '🙅 🏾 \u200d ♀ ️',
 '🙅 🏼 \u200d ♀ ️',
 '🙅 🏽 \u200d ♀ ️',
 '😠',
 '👿',
 '😵',
 '😱',
 '😮',
 '🙄',
 '😯',
 '🙆 \u200d ♂ ️',
 '🙆 🏿 \u200d ♂ ️',
 '🙆 🏻 \u200d ♂ ️',
 '🙆 🏾 \u200d ♂ ️',
 '🙆 🏼 \u200d ♂ ️',
 '🙆 🏽 \u200d ♂ ️',
 '🙆 \u200d ♀ ️',
 '🙆 🏿 \u200d ♀ ️',
 '🙆 🏻 \u200d ♀ ️',
 '🙆 🏾 \u200d ♀ ️',
 '🙆 🏼 \u200d ♀ ️',
 '🙆 🏽 \u200d ♀ ️',
 '😧',
 '😲',
 '🤞',
 '🤞 🏿',
 '🤞 🏻',
 '🤞 🏾',
 '🤞 🏼',
 '🤞 🏽',
 '😰',
 '😨',
 '😳',
 '😬',
 '🤢',
 '🤧'],
            'Emotion': ['Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Happy',
 'Sad',
 'Sad',
 'Sad',
 'Sad',
 'Sad',
 'Sad',
 'Sad',
 'Sad',
 'Sad',
 'Sad',
 'Sad',
 'Sad',
 'Sad',
 'Sad',
 'Sad',
 'Sad',
 'Sad',
 'Sad',
 'Sad',
 'Sad',
 'Sad',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Angry',
 'Surprise',
 'Surprise',
 'Surprise',
 'Surprise',
 'Surprise',
 'Surprise',
 'Surprise',
 'Surprise',
 'Surprise',
 'Surprise',
 'Surprise',
 'Surprise',
 'Surprise',
 'Surprise',
 'Surprise',
 'Surprise',
 'Surprise',
 'Surprise',
 'Surprise',
 'Fear',
 'Fear',
 'Fear',
 'Fear',
 'Fear',
 'Fear',
 'Fear',
 'Fear',
 'Fear',
 'Fear',
 'Fear',
 'Fear']}
    a = " ".join(c for c in text if c in emoji.EMOJI_DATA).split()
    for i in a:
        try:
            text = text.replace(i, " " + emoj['Emotion'][emoj["Emoji"].index(i)] + " ")
        except:
            pass
    return text.lower()


def cleaning(text):
    text = text.lower()
    text = emojis_extractor(text)
    text = re.sub(r'http\S+|www.\S+', '', text)
    text = removing_contradictions(text)
    text = removing_not(text)
    text = text.split()
    text = removing_shortcuts(text)
    text = ' '.join([i for i in text.split() if not i.isdigit()])
    text = word_tokenize(text)
    words_alpha = removing_stopwords(text)
    words_big = [word for word in words_alpha if len(word) > 2]
    clean_text = lemmatization(words_big)
    clean_text = clean_text.replace('   ', ' ')
    clean_text = clean_text.replace('  ', ' ')
    # print(clean_text)
    return clean_text


def get_emotion(input):
    df = {'Word': ['out of sight', 'owning it', 'great', 'excitation', 'ecstatic', 'enthralling', 'delighted', 'renovation', 'eased', 'amicable', 'smiling', 'sick', 'merry', 'massage', 'glad', 'mouth-watering', 'kicking it', 'happy', 'hella dope', 'outburst', 'sensuous', 'glee', 'pray', 'accomplished', 'cared for', 'incredible', 'liquor', 'soundness', 'jubilant', 'whim', 'care', 'pleasurable', 'commendable', 'easy', 'radiant', 'getting after it', 'crowning', 'completing', 'tree', 'roadster', 'glitter', 'winner', 'admirable', 'splendid', 'satisfied', 'persuasive', 'having a good time', 'dope', 'purify', 'dominating', 'sanctification', 'helpful', 'award', 'medal', 'reconciliation', 'amusement', 'supported', 'morals', 'exhilaration', 'unsurpassed', 'shining', 'secure', 'psyched', 'saint', 'fortune', 'evolved', 'intense', 'blissful', 'transcendence', 'prestige', 'entertain', 'inseparable', 'stunning', 'angel', 'appreci
it', 'crushing it', 'hip', 'healing', 'widower', 'annoyance', 'leprosy', 'sick', 'pornography', 'arrogant', 'adversity', 'committal', 'restriction', 'fatigued', 'diabolical', 'loss', 'banshee', 'downhearted', 'troubled', 'farcical', 'impurity', 'plaintive', 'criminality', 'glitter', 'dreadful', 'subsidy', 'runaway', 'sly', 'queasy', 'poaching', 'exigent', 'absent', 'vulgarity', 'fatty', 'lush', 'exile', 'cheated', 'intense', 'theocratic', 'famine', 'lynch', 'unhealthy', 'blindness', 'copycat', 'exploited', 'villainous', 'disagreeing', 'abundance', 'invade', 'insult', 'displeased', 'guarded', 'repulsion', 'inhuman', 'punishment', 'mortuary', 'harmful', 'filth', 'blame', 'dilapidated', 'ignorant', 'arid', 'censor', 'insanity', 'hopelessness', 'wrinkled', 'pressed', 'polemic', 'sinful', 'sonnet', 'ashes', 'devastation', 'terminate', 'indecent', 'sordid', 'callous', 'dank', 'baboon', 'unconscionable', 'joyless', 'muff', 'pitiful', 'collapse', 'loathe', 'mistake', 'crap', 'prostitute', 'lusty', 'darken', 'shoplifting', 'perishing', 'theft', 'crushed', 'taunt', 'surgery', 'inter', 'terminal', 'mucus', 'delusion', 'wrecked', 'deflate', 'ignored', 'depressive', 'fault', 'defunct', 'detainee', 'flesh', 'assailant', 'panicked', 'terribly', 'ravenous', 'slimy', 'die', 'deterioration', 'hostility', 'stingy', 'sprain', 'complacent', 'whimper', 'anxious', 'apologize', 'laxative', 'repentant', 'incubus', 'lurid', 'gonorrhea', 'cadaver', 'shiver', 'poisonous', 'instinctive', 'disobey', 'art', 'misery', 'panic', 'couch', 'saturated', 'unclean', 'offensive', 'bloodthirsty', 'decomposed', 'abyss', 'rejects', 'disqualify', 'problem', 'dark', 'chaos', 'puzzled', 'horrid', 'damn', 'bottom', 'contempt', 'retirement', 'tomb', 'betrayal', 'peril', 'downtrodden', 'loveless', 'insurmountable', 'plunder', 'evanescence', 'irreconcilable', 'trapped', 'subsidence', 'thirst', 'fraudulent', 'dabbling', 'dictatorship', 'nothingness', 'denunciation', 'persecution', 'disheartening', 'wrongly', 'useless', 'napkin', 'infidel', 'sludge', 'loathing', 'tripping', 'offend', 'substandard', 'dislocated', 'perpetrator', 'skeptical', 'bugaboo', 'dame', 'detention', 'gelatin', 'prosecute', 'louse', 'longing', 'tough', 'disfavor', 'hell', 'smut', 'casket', 'overdue', 'incurable', 'paralysis', 'depravity', 'bloodshed', 'cemetery', 'atherosclerosis', 'greasy', 'depressing', 'tax', 'weight', 'discriminate', 'illegitimate', 'intolerant', 'scream', 'ooze', 'battered', 'crazy', 'shaky', 'unsuccessful', 'disease', 'noncompliance', 'bile', 'uninvited', 'frighten', 'actionable', 'discrimination', 'down', 'subdued', 'bigot', 'cannibalism', 'malicious', 'pollute', 'bankrupt', 'rigor', 'miscarriage', 'losing', 'perplexity', 'suffocating', 'unlucky', 'drained', 'refused', 'antichrist', 'not diverse', 'paucity', 'uncheerful', 'vote', 'appendicitis', 'diminish', 'humiliation', 'fleece', 'chargeable', 'daemon', 'secluded', 'unseat', 'molestation', 'lockup', 'offender', 'illiterate', 'ail', 'bummed', 'sympathize', 'unfair', 'dastardly', 'heavyhearted', 'unwelcome', 'pessimism', 'squall', 'low', 'scarcity', 'stalemate', 'negro', 'disallowed', 'oppression', 'obliging', 'offense', 'cumbersome', 'rash', 'critter', 'bickering', 'flaw', 'hurt', 'servile', 'weird', 'sigh', 'unemployed', 'destitute', 'endocarditis', 'requiem', 'worthless', 'mutiny', 'loo', 'starvation', 'raw', 'sob', 'debacle', 'freakish', 'departed', 'confined', 'overpriced', 'carelessness', 'scourge', 'homicide', 'provoking', 'tempest', 'pine', 'decay', 'eschew', 'gag', 'wistful', 'measles', 'derision', 'manslaughter', 'lousy', 'stressed', 'reprisal', 'stricken', 'unhappiness', 'presumptuous', 'barf', 'prohibited', 'aftermath', 'blemish', 'wane', 'somber', 'irritated', 'left out', 'insecure', 'swarm', 'tense', 'grave', 'orchestra', 'badly', 'heartfelt', 'uneasy', 'imposter syndrome', 'uninterested', 'nauseous', 'inept', 'reflux', 'excluded', 'despicable', 'beg', 'impure', 'smite', 'prosecution', 'gratuitous', 'depression', 'wail', 'ugly', 'toad', 'pervert', 'overwhelmed', 'breakup', 'esteem', 'larger', 'explode', 'pus', 'destination', 'homesick', 'squeamish', 'untoward', 'deprivation', 'burnt out', 'throb', 'infertility', 'paralyzed', 'mad', 'rating', 'depreciated', 'hairy', 'pillage', 'necessity', 'cremation', 'vulnerability', 'rupture', 'drivel', 'perversion', 'attenuation', 'stealing', 'endless', 'smuggler', 'fierce', 'snort', 'pimple', 'deserted', 'afraid', 'sickened', 'sunk-in', 'death', 'warp', 'unwanted', 'boil', 'unfortunate', 'worn-out', 'hostile', 'soil', 'pestilence', 'hatred', 'cupping', 'disillusionment', 'fool', 'crumbling', 'doomsday', 'jarring', 'thoughtless', 'difficulties', 'retribution', 'abject', 'wither', 'untitled', 'disgraceful', 'goblin', 'prolong', 'pauper', 'sacrifices', 'antisocial', 'sorrowful', 'sullen', 'disappoint', 'tree', 'teary-eyed', 'ugliness', 'accident', 'stripped', 'sore', 'precarious', 'rascal', 'punished', 'dreadfully', 'cruelty', 'bitch', 'rheumatism', 'irreparable', 'dispirited', 'stifled', 'slaughtering', 'sour', 'fortress', 'spew', 'incompatible', 'discouraging', 'inadequate', 'deform', 'slug', 'tearful', 'leave', 'contentious', 'criticism', 'constraint', 'litigious', 'sabotage', 'grotesque', 'apathetic', 'cuckold', 'remorse', 'drop out', 'hydrocephalus', 'tribulation', 'sufferer', 'seriousness', 'pollution', 'stress', 'undertaker', 'dire', 'hulk', 'dispassionate', 'flagrant', 'dreary', 'inefficiency', 'distrust', 'sisterhood', 'incrimination', 'gutter', 'embarrass', 'evict', 'maggot', 'crippled', 'desist', 'asymmetry', 'inhibit', 'disappointing', 'grievous', 'pious', 'swampy', 'delirious', 'unpublished', 'hobo', 'inmate', 'doleful', 'wildfire', 'darkness', 'oppressor', 'homeless', 'hamstring', 'earthquake',
', 'grated', 'grab', 'distressed', 'abhorrent', 'torture', 'slay', 'gibberish', 'irritating', 'rejection', 'abuse', 'frustration', 'appalled', 'broil', 'distraught', 'impertinent', 'decry', 'vendetta', 'lava', 'gall', 'executioner', 'bothering', 'meddle', 'defiance', 'anathema', 'tolerate', 'wrangling', 'snappy', 'teasing', 'bankruptcy', 'stab', 'barrier', 'hoot', 'slam', 'scandalous', 'blackmail', 'eradicate', 'torment', 'suicide', 'difficult', 'frenzied', 'treason', 'retaliation', 'reproach', 'wop', 'impatient', 'latent', 'odious', 'psychosis', 'renegade', 'execution', 'riot', 'sectarian', 'unforgiving', 'cutting', 'detest', 'revoke', 'shameful', 'disapproved', 'ill-natured', 'litigate', 'perverse', 'tired', 'annoyed', 'opposition', 'contraband', 'extinguish', 'evade', 'gore', 'chagrined', 'disrespect', 'legalized', 'violently', 'tariff', 'involution', 'antagonist', 'badger', 'impolite', 'disparage', 'clashing', 'slur', 'destroyed', 'rapping', 'argumentation', 'immorality', 'strangle', 'provoked', 'penitentiary', 'barbaric', 'anarchist', 'conflict', 'tension', 'disillusioned', 'eradication', 'anguish', 'disgusted', 'dissolution', 'let down', 'banishment', 'vengeance', 'uncertain', 'birch', 'traumatic', 'attorney', 'opposed', 'kicking', 'menacing', 'trickery', 'treachery', 'powerless', 'infidelity', 'dismayed', 'rocket', 'shout', 'loudness', 'fervor', 'sore at', 'slap', 'rebellion', 'dumps', 'scoundrel', 'demolish', 'disparaging', 'bloody', 'unequal', 'brute', 'implicate', 'brassy', 'accusation', 'corrupting', 'prejudicial', 'annoy', 'scold', 'annoying', 'disapproving', 'wince', 'unattainable', 'unthinkable', 'beating', 'embarrassed', 'disruption', 'alienation', 'murderer', 'wasted', 'illegality', 'malpractice', 'disdain', 'condemnation', 'transphobia', 'abhor', 'upset', 'ulcer', 'infuriated', 'vehement', 'cursed', 'discord', 'disgruntled', 'loathsome', 'betray', 'abolish', 'worn out', 'menace', 'demonic', 'kick', 'avarice', 'melodrama', 'belittle', 'scare', 'desert', 'defamatory', 'waffle', 'undesirable', 'witch', 'disgruntledproblem', 'disgusting', 'pernicious', 'crusade', 'quandary', 'inconvenient', 'boxing', 'growl', 'collision', 'sarcasm', 'deadly', 'lying', 'moral', 'powerful', 'resisting', 'egregious', 'accursed', 'onerous', 'libel', 'claimant', 'mastery', 'renounce', 'blasphemy', 'bored', 'haughty', 'belt', 'indifference', 'cad', 'bad', 'fighting', 'scoff', 'howl', 'hard to please', 'bombardment', 'irritability', 'contemptible', 'incarceration', 'out of sorts', 'gory', 'kidnap', 'combat', 'brimstone', 'prisoner', 'peevish', 'musical', 'toxic', 'fear', 'scar', 'demand', 'madman', 'bullying', 'words', 'lose', 'unjustifiable', 'deficient', 'done', 'malign', 'raging', 'misbehavior', 'miffed', 'manipulation', 'fuss', 'destroying', 'despise', 'conspirator', 'inattention', 'horrible', 'stigma', 'unlawful', 'cancel', 'insidious', 'satanic', 'feeling', 'erupt', 'savagery', 'senseless', 'adverse', 'fu
flu', 'forced', 'foreigner', 'fret', 'gash', 'gasping', 'ghostly', 'government', 'grenade', 'grizzly', 'guerilla', 'hallucination', 'hangman', 'harm', 'harrowing', 'haunt', 'hazard', 'hazardous', 'haze', 'hearing', 'heathen', 'heighten', 'hesitation', 'horrified', 'hurricane', 'hydra', 'hysteria', 'incursion', 'indefensible', 'indictment', 'infection', 'infirmity', 'inflation', 'insecurity', 'intimidate', 'intrusion', 'jaundice', 'locust', 'mace', 'mafia', 'mandamus', 'melee', 'mercenary', 'merciless', 'mistaken', 'monster', 'mum', 'muzzle', 'nightmare', 'obligor', 'ordnance', 'panic', 'paranoia', 'perturbation', 'phantom', 'pinion', 'plummet', 'plunge', 'pneumonia', 'predicament', 'premeditated', 'prey', 'punish', 'purge', 'quail', 'quash', 'quiver', 'quivering', 'radiation', 'radioactive', 'radon', 'raptors', 'regulatory', 'reluctant', 'repression', 'resistant', 'reticent', 'retrenchment', 'sag', 'scaffold', 'scalpel', 'scandal', 'seize', 'shady', 'shaking', 'shudder', 'siren', 'smuggle', 'snare', 'sortie', 'soulmate', 'spasm', 'spook', 'sprite', 'stalk', 'stormy', 'straits', 'stranger', 'subordinate', 'suspect', 'suspension', 'suspicion', 'swelling', 'terror', 'thorny', 'toothache', 'toxin', 'trembling', 'tumor', 'turbulent', 'typhoon', 'unholy', 'unsafe', 'unspeakable', 'vertigo', 'villain', 'viper', 'war', 'ware', 'waver', 'weirdo', 'whirlwind', 'wicked', 'xenophobia', 'bailiff', 'bait', 'dubious', 'accidental', 'alarm', 'alarming', 'anomaly', 'bewildered', 'cyclone', 'detonate', 'examination', 'explosion', 'fright', 'frightened', 'infarct', 'perjury', 'screech', 'startle', 'stunned', 'uncanny', 'unstable', 'volcano', 'abandon', 'absence', 'abyss', 'afflict', 'ailing', 'appendicitis', 'atherosclerosis', 'austere', 'bankrupt', 'battered', 'bier', 'blackness', 'blues', 'bondage', 'broke', 'burdensome', 'buried', 'captive', 'carcinoma', 'cardiomyopathy', 'case', 'casket', 'cemetery', 'chargeable', 'coffin', 'coma', 'comatose', 'cripple', 'crypt', 'cyst', 'danger', 'darken', 'darkened', 'debacle', 'decay', 'defenseless', 'dementia', 'demise', 'demoralized', 'dependence', 'deport', 'depress', 'desolation', 'despairing', 'destitute', 'deteriorate', 'die', 'disable', 'disabled', 'discourage', 'disembodied', 'doomed', 'downfall', 'drown', 'dwarfed', 'emaciated', 'embolism', 'euthanasia', 'evasion', 'exorcism', 'exterminate', 'fatality', 'fearful', 'flounder', 'foreclose', 'forfeiture', 'forgotten', 'fragile', 'fraught', 'grave', 'grieve', 'grounded', 'halting', 'haunted', 'hearse', 'helpless', 'helplessness', 'hopeless', 'horrors', 'illness', 'incrimination', 'infliction', 'injured', 'insurmountable', 'irreparable', 'isolated', 'jail', 'jarring', 'kill', 'knell', 'landslide', 'languishing', 'lifeless', 'lockup', 'loneliness', 'malignancy', 'martyr', 'martyrdom', 'miscarriage', 'misfortune', 'missing', 'mortuary', 'neuralgia', 'neurosis', 'obliteration', 'orphan', 'pain', 'pained', 'pandemic', 'penal', 'perish', 'perishing', 'pessimist', 'polio', 'problem', 'relapse', 'rubble', 'ruin', 'sarcoma', 'scarce', 'senile', 'sepsis', 'shipwreck', 'shrink', 'sorrow', 'specter', 'speculation', 'spinster', 'squall', 'starvation', 'stint', 'stroke', 'sufferer', 'surrender', 'terminal', 'throb', 'timid', 'tragedy', 'tribulation', 'tumour', 'tyranny', 'unemployed', 'vulnerability', 'wail', 'wan', 'weakly', 'worse', 'doubt', 'insolvent', 'abduction', 'accident', 'avalanche', 'crash', 'deluge', 'embarrassment', 'emergency', 'fainting', 'fearfully', 'frighten', 'insolvency', 'rupture', 'syncope', 'vanished', 'wildfire', 'omnipotence', 'scarecrow', 'seclusion', 'superstition', 'synonymous', 'buck', 'acrobat', 'confidence', 'intelligence', 'surprise', 'loyal', 'sympathetic', 'socialism', 'spider', 'hypertrophy', 'tearful', 'abominable', 'alien', 'anaconda', 'appalling', 'bacterium', 'beastly', 'bestial', 'blob', 'bug', 'burglar', 'cannibal', 'contagious', 'creature', 'debauchery', 'defamation', 'devilish', 'disintegrate', 'ghastly', 'goblin', 'grisly', 'hag', 'idolatry', 'impeach', 'incubus', 'infestation', 'inmate', 'instability', 'irrational', 'laxative', 'leeches', 'mange', 'mistrust', 'neurotic', 'noxious', 'obi', 'occult', 'ogre', 'parasite', 'pestilence', 'prejudiced', 'purgatory', 'rat', 'repellant', 'repulsion', 'rigor', 'robber', 'serpent', 'shanghai', 'smut', 'snake', 'squeamish', 'stealing', 'swamp', 'swampy', 'taboo', 'uneasy', 'unnatural', 'vulture', 'wimp', 'aghast', 'freakish', 'abortion', 'affliction', 'anthrax', 'arsenic', 'atrophy', 'autopsy', 'bacteria', 'bleeding', 'blight', 'carcass', 'cholera', 'collapse', 'contaminated', 'coward', 'cringe', 'cupping', 'decomposition', 'default', 'deformity', 'degrading', 'discontinuity', 'diseased', 'dismal', 'dismemberment', 'endemic', 'exclusion', 'failure', 'ghetto', 'hemorrhage', 'hideous', 'horrifying', 'hydrocephalus', 'ineptitude', 'infectious', 'lament', 'leprosy', 'lethal', 'malaria', 'measles', 'morgue', 'outcast', 'palsy', 'plague', 'retard', 'rot', 'sacrifices', 'servile', 'shame', 'sickness', 'soulless', 'subvert', 'suffering', 'suffocating', 'sunk', 'tramp', 'travesty', 'ugliness', 'unhealthy', 'varicella', 'wasting', 'woe', 'cadaver', 'dire', 'dreadfully', 'mishap', 'nefarious', 'remains', 'eventuality', 'expose', 'imminent', 'impending', 'prognosis', 'watch', 'alerts', 'blindfold', 'mysterious', 'suspense', 'urgency', 'warned', 'probation', 'wilderness', 'buzz', 'heft', 'towering', 'withstand', 'cautious', 'medical', 'alertness', 'anxious', 'apprehensive', 'beware', 'dread', 'endanger', 'foreboding', 'forewarned', 'jeopardy', 'loom', 'nervous', 'omen', 'ominous', 'overthrow', 'risk', 'risky', 'superstitious', 'timidity', 'undecided', 'unknown', 'verge', 'diagnosis', 's
 'delusion', 'deportation', 'depressed', 'destroyed', 'destroying', 'devastate', 'difficulty', 'disastrous', 'dispossessed', 'domination', 'encumbrance', 'enmity', 'executioner', 'exile', 'fatal', 'frightful', 'fury', 'gallows', 'grievous', 'halter', 'hurt', 'hurting', 'impotence', 'inequality', 'inflict', 'injure', 'injurious', 'injury', 'insecure', 'invader', 'irreconcilable', 'killing', 'leukemia', 'loss', 'militia', 'mortality', 'mournful', 'nether', 'obliterate', 'obstacle', 'oppressor', 'penalty', 'pernicious', 'pessimism', 'prison', 'prosecute', 'psychosis', 'punishing', 'punitive', 'rating', 'ravenous', 'reject', 'rejects', 'remove', 'reprisal', 'resisting', 'restriction', 'retribution', 'revolver', 'rheumatism', 'scarcity', 'scourge', 'scrapie', 'shortage', 'skid', 'slave', 'smite', 'spank', 'steal', 'stifled', 'struggle', 'suicide', 'suppress', 'taunt', 'terrorize', 'thresh', 'torment', 'traumatic', 'turmoil', 'upheaval', 'vendetta', 'victim', 'violence', 'warfare', 'witchcraft', 'wound', 'wrecked', 'wrongly', 'execution', 'theocratic', 'abandonment', 'bomb', 'defy', 'devastation', 'dissolution', 'disturbance', 'earthquake', 'explode', 'invade', 'kidnap', 'paralyzed', 'punch', 'shatter', 'shell', 'shot', 'shriek', 'stab', 'treachery', 'violation', 'armed', 'dominate', 'enforce', 'mug', 'lace', 'legalized', 'mighty', 'endless', 'outburst', 'elf', 'rebellion', 'instinctive', 'abhor', 'abhorrent', 'abomination', 'antichrist', 'averse', 'aversion', 'badness', 'bane', 'barbaric', 'bigot', 'birch', 'bloodthirsty', 'brawl', 'butcher', 'coerce', 'contempt', 'contentious', 'contraband', 'criminal', 'criminality', 'crushing', 'cur', 'dastardly', 'defiance', 'deleterious', 'denunciation', 'deranged', 'destructive', 'diabolical', 'disgusting', 'disreputable', 'distrust', 'enemy', 'eradication', 'evade', 'ferocious', 'fiend', 'fierce', 'foul', 'gent', 'gnome', 'grope', 'growling', 'hardened', 'hood', 'horrible', 'hostile', 'illegality', 'illicit', 'infamous', 'infidel', 'insidious', 'intolerance', 'lawyer', 'lunatic', 'masochism', 'misconception', 'odious', 'orc', 'perverse', 'pest', 'pillage', 'possessed', 'possession', 'prohibited', 'punishment', 'raging', 'rascal', 'repellent', 'revolting', 'revulsion', 'ruthless', 'screaming', 'sinister', 'sly', 'smuggler', 'suppression', 'threatening', 'thug', 'treacherous', 'tyrannical', 'unjustifiable', 'unruly', 'unsettled', 'unthinkable', 'vampire', 'venom', 'venomous', 'vermin', 'villainous', 'witch', 'censor', 'scoundrel', 'intrusive', 'monstrosity', 'mutiny', 'prick', 'recklessness', 'scorpion', 'scream', 'treason', 'uncertain', 'violent', 'abuse', 'adder', 'adverse', 'aftermath', 'alcoholism', 'alienation', 'anathema', 'animosity', 'antisocial', 'atrocity', 'awful', 'bad', 'banish', 'bankruptcy', 'banshee', 'belittle', 'bigoted', 'bitch', 'blemish', 'bloody', 'burke', 'cancer', 'coercion', 'coldness', 'collusion', 'confined', 'convict
happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Happy', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Angry', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Fear', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral']}
    text = cleaning(input).split()
    emotion_values = []
    emotions = {"Happy": 0, "Sad": 0, "Angry": 0, "Fear":0, "Neutral": 0}
    y = 0
    try:
        for i in text:
            try:
                a = df['Word'].index(i)
                if a:
                    emotions[df['Emotion'][a]] += 1
            except:
                pass
        if sum(emotions.values()) is 0:
            return emotions
        for i in emotions:
            emotion_values.append(round((emotions[i] / sum(emotions.values())), 2))
        for j in emotions:
            emotions[j] = emotion_values[y]
            y += 1
        return emotions
    except:
        pass
# Out:
# <>:669: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:669: SyntaxWarning: "is" with a literal. Did you mean "=="?
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# <ipython-input-8-0e369c052f82>:669: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if sum(emotions.values()) is 0:

# %%
get_emotion("“Choosing to go to Pomona was the best decision of my life. Amazing professors and amazing people. The other 5Cs make up for what Pomona lacks in food diversity or social scene. I love this place and cannot recommend it enough.”")
# Out:
# {'Happy': 0.67, 'Sad': 0.33, 'Angry': 0.0, 'Fear': 0.0, 'Neutral': 0.0}

# %%
#My Code // Additions is down below

# %%
#this is from my categorizing file
#the code that sorts
premade_categories = ["athletics", "social", "academics", "location", "prestige", "affordability","environment"]

athletics = ["sport", "sports", "sporting", "athletics", "athletes", "athlete", "championship","champion","playoff", "playoffs", "basketball","football","tennis","softball","baseball","water polo","rugby","PE","physical","swim"]
social = ["party","friend","celebration","fraternity","frat","sorority","culture","dorm","drinking","social","network","environment","communities","clubs"]
academics = ["teacher","professor","professors","academics","classes","education","class","registration","accommodations","exams","cheat","test","homework","problem","staff","faculty","grade","grading",'study','opportunities','co-op','research','undergrad','graduate','program']
location = ["campus","located","area","city","community","nature","nearby","outdoor","far away","local"]
prestige = ["prestige","prestigious","honor","famous","rank","ranking","top","well-known"]
affordability = ["afford","cost","price","expensive","cheap","expensive", 'worth']
environment = ["workaholism", 'competitive', "stress", "chill","fun",'lazy','enjoyable',"experience",'relaxed','easy','hard','doable','hate']

# %%
#function
def classify(text):
  """This function takes in a block of text and returns the category(ies) it is in."""
  text = text.translate(str.maketrans("", "", string.punctuation))
  categories = []
  for word in text.lower().split():
    if word in athletics:
      categories.append('athletics')
    if word in social:
      categories.append("social")
    if word in academics:
      categories.append("academics")
    if word in location:
      categories.append("location")
    if word in prestige:
      categories.append("prestige")
    if word in affordability:
      categories.append("affordability")
    if word in environment:
      categories.append("environment")

  return set(categories)

# %%
#this function will sort the reviews from a given college into a dictionary
def sorter(college_name):
  labeledReviews = {}

  #Dynamically creating the labeledReviews just in case we get more categories in the future
  for category in premade_categories:
    labeledReviews[category] = []

  #Getting the reviews 
  allReviews = reviews(college_name)
  for review in allReviews:
    categories = classify(review)
    #For each category assign the review to the corresponding key
    for category in categories:
      if(len(labeledReviews[category]) == 0):
        labeledReviews[category].append(review)
      else:
        labeledReviews[category][0] += review

  return labeledReviews
    


print(sorter("Pomona College"))
# Out:
# {'athletics': [], 'social': ["Choosing to go to Pomona was the best decision of my life. Amazing professors and amazing people. The other 5Cs make up for what Pomona lacks in food diversity or social scene. I love this place and cannot recommend it enough.This relatively unknown attracts students who are as distinguished as anyone in the Ivy League. The climate, however, is a lot more laid-back and nurturing. There are (mostly) pros and (some) cons. You'll get a world-class education here with immeasurable opportunity. But our alumni network is lacking, and it is easy to become complacent here."], 'academics': ["Pomona has been the best decision of my life. You get a diverse, intelligent set of people who are all passionate and you're bound to grow and challenge yourself here. The resources are great, there's some grade inflation, the location is solid and the food is good (with other schools) as well.Choosing to go to Pomona was the best decision of my life. Amazing professors and a
# ...

# %%
def visualization(text):
  """This function takes in the text and returns a visual representation of the text2emotion data that corresponds with the text2emotion values. If we want to update the sides, we would have to do it through the text2emotion."""
  # convert dictionary into data frame
  textDictionary = get_emotion(text)
  values = textDictionary.values()
  keys = textDictionary.keys()
  df = pd.DataFrame(dict(r=values,theta=keys))

  #debug
  print(df)

  #visualizing the graph
  fig = px.line_polar(df, r='r', theta='theta', line_close=True)
  fig.update_traces(fill='toself')
  fig.show()

# %%
labeledReviews = sorter("Stanford University")
for key, value in labeledReviews.items():
  for review in value:
    print(key)
    print(review)
    visualization(review)
# Out:
# athletics
# I visited H,Y,P, MIT, but once I visited Stanford my choice was made. The beauty, atmosphere, academics, school spirit, and sports captured me. It has everything HYP can offer and MIT. Stanford would be the baby conceived between Harvard and MIT academically, but with added benefits such as friendliness, welcoming, and warmth. I am quite happy hereI visited Harvard, Yale, Princeton, and MIT, but once I visited Stanford my choice was made. It's beauty, atmosphere, academics, sports, and school spirit captured me. It has everything HYP can offer plus MIT. As a student in engineering Stanford would be the baby between Harvard and MIT academically, but with added benefits like warm and friendly
#      r    theta
# 0  1.0    Happy
# 1  0.0      Sad
# 2  0.0    Angry
# 3  0.0     Fear
# 4  0.0  Neutral
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py:271: FutureWarning:
#
# ...

# %%
labeledReviews = sorter("Harvard University")
for key, value in labeledReviews.items():
  for review in value:
    print(key)
    print(review)
    visualization(review)
# Out:
# academics
# ...

# %%
labeledReviews = sorter("Pomona College")
for key, value in labeledReviews.items():
  for review in value:
    print(key)
    print(review)
    visualization(review)
# Out:
# social
# Choosing to go to Pomona was the best decision of my life. Amazing professors and amazing people. The other 5Cs make up for what Pomona lacks in food diversity or social scene. I love this place and cannot recommend it enough.This relatively unknown attracts students who are as distinguished as anyone in the Ivy League. The climate, however, is a lot more laid-back and nurturing. There are (mostly) pros and (some) cons. You'll get a world-class education here with immeasurable opportunity. But our alumni network is lacking, and it is easy to become complacent here.
#      r    theta
# 0  0.6    Happy
# 1  0.3      Sad
# 2  0.0    Angry
# 3  0.1     Fear
# 4  0.0  Neutral
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py:271: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
# ...

# %%
labeledReviews = sorter("University of California Los Angeles (UCLA)")
for key, value in labeledReviews.items():
  for review in value:
    print(key)
    print(review)
    visualization(review)
# Out:
# social
# You can get a great party life from this school but OVERALL its alright not all the hype.Rep: overrated. Location: nice at first but it feels like a bubble over time. Opportunity: good opportunities, but hard to compete with 30,000+ undergrads for slim pickings. Common areas: just ew. Internet: good except when walking around. Food: good for college but not that good. Clubs: lots. Social: parties Thurs-Sat. Happiness: ;(. Safety: safe.I really enjoyed it. L.A. is a cosmopolitan environment, and UCLA is an even higher than top quality university.UCLA is distinguished, the alumni network is incredible, and there are countless opportunities. However, it IS a Tier 1 public research university, and that means that professors' top priority is not teaching, but contributing research to their fields. The student body is large, so you have to make your own way through and advocate for yourself.
#       r    theta
# 0  0.80    Happy
# 1  0.07      Sad
# 2  0.00    Angry
# ...

# %%
labeledReviews = sorter("Hamilton College")
for key, value in labeledReviews.items():
  for review in value:
    print(key)
    print(review)
    visualization(review)
# Out:
# athletics
# Great school for academics in just about anything they offer. Has a nice balance between super chill people n those that grind. Wish the campus had more of a community feel and was more socially aware as a whole. Join academic clubs, any sports team (club or varsity) or music group and you're basically guaranteed a great group of friends.As long as you know that this is a school in upstate ny in a small town when you apply, you will love it. It snows, but its gorgeous. Club sports are really fun, teachers are all fantastic, and you will make great friends. Whenever you speak to alumni, they only have positive things to say. With good friends, you can have a great nightlife. Love it
#       r    theta
# 0  0.94    Happy
# 1  0.06      Sad
# 2  0.00    Angry
# 3  0.00     Fear
# 4  0.00  Neutral
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py:271: FutureWarning:
#
# ...

# %%
labeledReviews = sorter("University of Chicago")
for key, value in labeledReviews.items():
  for review in value:
    print(key)
    print(review)
    visualization(review)
# Out:
# social
# i love it here beyond words. regardless of what people say, there are plenty of parties on campus and clubs downtown to go to!! great work hard, play hard environment 1/10 This school ruins your mental health ! Would have gone somewhere else if I had to redo college. There are nice people but overall the students are depressed and often rude. The clubs are all boring because people cannot be as engaged as they want to with all their course work. I gave it a 1/10 because the snow is pretty and the campus is, too.Great school that is getting a bit more social every year.
#       r    theta
# 0  0.46    Happy
# 1  0.38      Sad
# 2  0.15    Angry
# 3  0.00     Fear
# 4  0.00  Neutral
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py:271: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
# ...

# %%
labeledReviews = sorter("University of Rochester")
for key, value in labeledReviews.items():
  for review in value:
    print(key)
    print(review)
    visualization(review)
# Out:
# social
# An excellent school, especially for engineering and sciences. You should know that it leans to the theoretical side of things, which can be frustrating if you're more interested in focusing on practical application. Rochester isn't the sexiest city out there, but it does have character and culture to offer.
#      r    theta
# 0  0.5    Happy
# 1  0.5      Sad
# 2  0.0    Angry
# 3  0.0     Fear
# 4  0.0  Neutral
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py:271: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
# ...

# %%
labeledReviews = sorter("Bucknell University")
for key, value in labeledReviews.items():
  for review in value:
    print(key)
    print(review)
    visualization(review)
# Out:
# athletics
# ...

# %%
labeledReviews = sorter("Brown University")
for key, value in labeledReviews.items():
  for review in value:
    print(key)
    print(review)
    visualization(review)
# Out:
# athletics
# Best school. The happiness is contagious and academically it lives up to its brilliant expectation. The school spirit at Brown doesn't show at the sports games but rather on a day to day basis in every ounce of conversation. We love Brown, and Brown loves its students.
#      r    theta
# 0  0.8    Happy
# 1  0.2      Sad
# 2  0.0    Angry
# 3  0.0     Fear
# 4  0.0  Neutral
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py:271: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
# ...

# %%
labeledReviews = sorter("University of Wisconsin - Madison")
for key, value in labeledReviews.items():
  for review in value:
    print(key)
    print(review)
    visualization(review)
# Out:
# social
# ...
